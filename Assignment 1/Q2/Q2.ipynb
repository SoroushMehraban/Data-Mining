# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read data

# %%
df = pd.read_csv('players.csv')
df
# Out:
#            ID               Name                      FullName  Age  Height  \
# 0      158023           L. Messi                  Lionel Messi   33     170
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   35     187
# 2      200389           J. Oblak                     Jan Oblak   27     188
# 3      192985       K. De Bruyne               Kevin De Bruyne   29     181
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.   28     175
# ...       ...                ...                           ...  ...     ...
# 19015  257371        M. Nzongong                 Mike Nzongong   19     179
# 19016  259160            L. Bell                    Lewis Bell   17     181
# 19017  259157            Y. Arai                    Yasin Arai   16     176
# 19018  253763         R. Dinanga               Ricardo Dinanga   18     174
# 19019  241493      S. Cartwright             Samuel Cartwright   19     185
#
#        Weight                                          PhotoUrl  \
# 0          72  https://cdn.sofifa.com/players/158/023/21_60.png
# 1          83  https://cdn.sofifa.com/players/020/801/21_60.png
# 2          87  https://cdn.sofifa.com/players/200/389/21_60.png
# 3          70  https://cdn.sofifa.com/players/192/985/21_60.png
# 4          68  https://cdn.sofifa.com/players/190/871/21_60.png
# ...       ...                                               ...
# 19015      74  https://cdn.sofifa.com/players/257/371/21_60.png
# 19016      70  https://cdn.sofifa.com/players/259/160/21_60.png
# 19017      70  https://cdn.sofifa.com/players/259/157/21_60.png
# 19018      73  https://cdn.sofifa.com/players/253/763/21_60.png
# 19019      75  https://cdn.sofifa.com/players/241/493/21_60.png
#
#                Nationality  Overall  Potential  ...  LMRating  CMRating  \
# 0                Argentina       93         93  ...        93        90
# 1                 Portugal       92         92  ...        91        84
# 2                 Slovenia       91         93  ...        38        41
# 3                  Belgium       91         91  ...        91        91
# 4                   Brazil       91         91  ...        91        86
# ...                    ...      ...        ...  ...       ...       ...
# 19015  Republic of Ireland       49         60  ...        51        47
# 19016              England       49         67  ...        51        44
# 19017              England       49         74  ...        53        47
# 19018  Republic of Ireland       49         59  ...        49        43
# 19019              England       49         65  ...        38        36
#
#        RMRating LWBRating CDMRating RWBRating  LBRating  CBRating  RBRating  \
# 0            93        69        68        69        65        55        65
# 1            91        68        64        68        64        57        64
# 2            38        35        39        35        35        36        35
# 3            91        82        83        82        78        72        78
# 4            91        70        65        70        65        52        65
# ...         ...       ...       ...       ...       ...       ...       ...
# 19015        51        44        42        44        42        40        42
# 19016        51        42        38        42        41        35        41
# 19017        53        45        40        45        44        39        44
# 19018        49        36        32        36        34        30        34
# 19019        38        46        45        46        47        51        47
#
#       GKRating
# 0           22
# 1           23
# 2           92
# 3           24
# 4           23
# ...        ...
# 19015       18
# 19016       13
# 19017       17
# 19018       16
# 19019       15
#
# [19020 rows x 90 columns]

# %% [markdown]
# ## a. showing first/last 5 rows

# %%
df.head()
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   33     170
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   35     187
# 2  200389           J. Oblak                     Jan Oblak   27     188
# 3  192985       K. De Bruyne               Kevin De Bruyne   29     181
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.   28     175
#
#    Weight                                          PhotoUrl Nationality  \
# 0      72  https://cdn.sofifa.com/players/158/023/21_60.png   Argentina
# 1      83  https://cdn.sofifa.com/players/020/801/21_60.png    Portugal
# 2      87  https://cdn.sofifa.com/players/200/389/21_60.png    Slovenia
# 3      70  https://cdn.sofifa.com/players/192/985/21_60.png     Belgium
# 4      68  https://cdn.sofifa.com/players/190/871/21_60.png      Brazil
#
#    Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# 0       93         93  ...        93        90        93        69        68
# 1       92         92  ...        91        84        91        68        64
# 2       91         93  ...        38        41        38        35        39
# 3       91         91  ...        91        91        91        82        83
# 4       91         91  ...        91        86        91        70        65
#
#   RWBRating  LBRating  CBRating  RBRating GKRating
# 0        69        65        55        65       22
# 1        68        64        57        64       23
# 2        35        35        36        35       92
# 3        82        78        72        78       24
# 4        70        65        52        65       23
#
# [5 rows x 90 columns]

# %%
df.tail()
# Out:
#            ID           Name           FullName  Age  Height  Weight  \
# 19015  257371    M. Nzongong      Mike Nzongong   19     179      74
# 19016  259160        L. Bell         Lewis Bell   17     181      70
# 19017  259157        Y. Arai         Yasin Arai   16     176      70
# 19018  253763     R. Dinanga    Ricardo Dinanga   18     174      73
# 19019  241493  S. Cartwright  Samuel Cartwright   19     185      75
#
#                                                PhotoUrl          Nationality  \
# 19015  https://cdn.sofifa.com/players/257/371/21_60.png  Republic of Ireland
# 19016  https://cdn.sofifa.com/players/259/160/21_60.png              England
# 19017  https://cdn.sofifa.com/players/259/157/21_60.png              England
# 19018  https://cdn.sofifa.com/players/253/763/21_60.png  Republic of Ireland
# 19019  https://cdn.sofifa.com/players/241/493/21_60.png              England
#
#        Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating  \
# 19015       49         60  ...        51        47        51        44
# 19016       49         67  ...        51        44        51        42
# 19017       49         74  ...        53        47        53        45
# 19018       49         59  ...        49        43        49        36
# 19019       49         65  ...        38        36        38        46
#
#       CDMRating RWBRating  LBRating  CBRating  RBRating GKRating
# 19015        42        44        42        40        42       18
# 19016        38        42        41        35        41       13
# 19017        40        45        44        39        44       17
# 19018        32        36        34        30        34       16
# 19019        45        46        47        51        47       15
#
# [5 rows x 90 columns]

# %% [markdown]
# ## b. Finding missing values

# %%
df[df.isnull().any(axis=1)]
# Out:
#            ID           Name                           FullName  Age  Height  \
# 4      190871      Neymar Jr         Neymar da Silva Santos Jr.   28     175
# 6      208722        S. Mané                         Sadio Mané   28     175
# 11     212831        Alisson              Alisson Ramses Becker   27     191
# 14     200145       Casemiro  Carlos Henrique Venancio Casimiro   28     185
# 16     165153     K. Benzema                      Karim Benzema   32     185
# ...       ...            ...                                ...  ...     ...
# 19015  257371    M. Nzongong                      Mike Nzongong   19     179
# 19016  259160        L. Bell                         Lewis Bell   17     181
# 19017  259157        Y. Arai                         Yasin Arai   16     176
# 19018  253763     R. Dinanga                    Ricardo Dinanga   18     174
# 19019  241493  S. Cartwright                  Samuel Cartwright   19     185
#
#        Weight                                          PhotoUrl  \
# 4          68  https://cdn.sofifa.com/players/190/871/21_60.png
# 6          69  https://cdn.sofifa.com/players/208/722/21_60.png
# 11         91  https://cdn.sofifa.com/players/212/831/21_60.png
# 14         84  https://cdn.sofifa.com/players/200/145/21_60.png
# 16         81  https://cdn.sofifa.com/players/165/153/21_60.png
# ...       ...                                               ...
# 19015      74  https://cdn.sofifa.com/players/257/371/21_60.png
# 19016      70  https://cdn.sofifa.com/players/259/160/21_60.png
# 19017      70  https://cdn.sofifa.com/players/259/157/21_60.png
# 19018      73  https://cdn.sofifa.com/players/253/763/21_60.png
# 19019      75  https://cdn.sofifa.com/players/241/493/21_60.png
#
#                Nationality  Overall  Potential  ...  LMRating  CMRating  \
# 4                   Brazil       91         91  ...        91        86
# 6                  Senegal       90         90  ...        90        84
# 11                  Brazil       90         91  ...        41        43
# 14                  Brazil       89         89  ...        77        84
# 16                  France       89         89  ...        87        83
# ...                    ...      ...        ...  ...       ...       ...
# 19015  Republic of Ireland       49         60  ...        51        47
# 19016              England       49         67  ...        51        44
# 19017              England       49         74  ...        53        47
# 19018  Republic of Ireland       49         59  ...        49        43
# 19019              England       49         65  ...        38        36
#
#        RMRating LWBRating CDMRating RWBRating  LBRating  CBRating  RBRating  \
# 4            91        70        65        70        65        52        65
# 6            90        72        68        72        69        62        69
# 11           41        34        38        34        33        33        33
# 14           77        83        89        83        84        89        84
# 16           87        66        66        66        62        58        62
# ...         ...       ...       ...       ...       ...       ...       ...
# 19015        51        44        42        44        42        40        42
# 19016        51        42        38        42        41        35        41
# 19017        53        45        40        45        44        39        44
# 19018        49        36        32        36        34        30        34
# 19019        38        46        45        46        47        51        47
#
#       GKRating
# 4           23
# 6           23
# 11          91
# 14          24
# 16          21
# ...        ...
# 19015       18
# 19016       13
# 19017       17
# 19018       16
# 19019       15
#
# [18118 rows x 90 columns]

# %%
df.isnull().sum()[df.isna().sum() > 0]
# Out:
# ClubPosition          234
# ContractUntil         234
# ClubNumber            234
# NationalPosition    17895
# NationalNumber      17895
# dtype: int64

# %% [markdown]
# ## c. Mean, min and max of player's weight

# %%
df['Weight'].mean()
# Out:
# 75.05241850683491

# %%
df['Weight'].min()
# Out:
# 50

# %%
df['Weight'].max()
# Out:
# 110

# %% [markdown]
# ## d. Finding countries which have most/least player numbers and corresponding numbers

# %%
min_count = df['Nationality'].value_counts().min()
df['Nationality'].value_counts()[df['Nationality'].value_counts() == min_count]
# Out:
# Indonesia              1
# Korea DPR              1
# Saint Lucia            1
# Hong Kong              1
# Malta                  1
# Singapore              1
# South Sudan            1
# Guatemala              1
# Barbados               1
# Chad                   1
# Suriname               1
# Papua New Guinea       1
# Andorra                1
# Rwanda                 1
# Guam                   1
# Bermuda                1
# Aruba                  1
# Tanzania               1
# Malawi                 1
# São Tomé & Príncipe    1
# New Caledonia          1
# Puerto Rico            1
# Malaysia               1
# Name: Nationality, dtype: int64

# %%
max_count = df['Nationality'].value_counts().max()
df['Nationality'].value_counts()[df['Nationality'].value_counts() == max_count]
# Out:
# England    1706
# Name: Nationality, dtype: int64

# %% [markdown]
# # e. Finding players who have Growth < 3 and Potential < 84

# %%
df[(df['Growth'] < 3) & (df['Potential'] < 84)]
# Out:
#            ID            Name                  FullName  Age  Height  Weight  \
# 139    169195  Renato Augusto            Renato Augusto   32     186      86
# 140    169416         C. Vela               Carlos Vela   31     177      77
# 143    215333       D. Zapata              Duván Zapata   29     189      88
# 144    216547            Rafa  Rafael A. Ferreira Silva   27     172      66
# 147    220407     M. Dúbravka           Martin Dúbravka   31     190      80
# ...       ...             ...                       ...  ...     ...     ...
# 18684  253744           Xu Wu                     Wu Xu   27     184      78
# 18742  256758        O. Alıcı                Ömer Alıcı   34     185      83
# 18888  157190      J. Russell              John Russell   35     172      70
# 18968  243073   Teng Shangkun             Shangkun Teng   29     186      78
# 18986  233720          Li Hao                    Hao Li   28     173      63
#
#                                                PhotoUrl          Nationality  \
# 139    https://cdn.sofifa.com/players/169/195/21_60.png               Brazil
# 140    https://cdn.sofifa.com/players/169/416/21_60.png               Mexico
# 143    https://cdn.sofifa.com/players/215/333/21_60.png             Colombia
# 144    https://cdn.sofifa.com/players/216/547/21_60.png             Portugal
# 147    https://cdn.sofifa.com/players/220/407/21_60.png             Slovakia
# ...                                                 ...                  ...
# 18684  https://cdn.sofifa.com/players/253/744/21_60.png             China PR
# 18742  https://cdn.sofifa.com/players/256/758/21_60.png               Turkey
# 18888  https://cdn.sofifa.com/players/157/190/21_60.png  Republic of Ireland
# 18968  https://cdn.sofifa.com/players/243/073/21_60.png             China PR
# 18986  https://cdn.sofifa.com/players/233/720/21_60.png             China PR
#
#        Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating  \
# 139         83         83  ...        82        83        82        79
# 140         83         83  ...        83        78        83        62
# 143         83         83  ...        75        68        75        56
# 144         83         83  ...        83        77        83        72
# 147         83         83  ...        37        41        37        33
# ...        ...        ...  ...       ...       ...       ...       ...
# 18684       52         54  ...        49        50        49        52
# 18742       51         51  ...        18        20        18        17
# 18888       50         50  ...        49        50        49        49
# 18968       50         51  ...        23        25        23        23
# 18986       50         51  ...        50        48        50        51
#
#       CDMRating RWBRating  LBRating  CBRating  RBRating GKRating
# 139          80        79        77        75        77       21
# 140          60        62        58        50        58       22
# 143          57        56        54        56        54       18
# 144          65        72        68        56        68       20
# 147          38        33        32        32        32       83
# ...         ...       ...       ...       ...       ...      ...
# 18684        53        52        52        52        52       16
# 18742        21        17        17        22        17       51
# 18888        50        49        49        50        49       16
# 18968        25        23        23        24        23       51
# 18986        51        51        51        51        51       16
#
# [8261 rows x 90 columns]

# %% [markdown]
# ## f. Bar chart of previous section based on Club position

# %%
extracted_players_positions = df[(df['Growth'] < 3) & (df['Potential'] < 84)]['ClubPosition']
positions_count = extracted_players_positions.value_counts()

fig = plt.figure(figsize=(20, 10))    
ax = fig.add_subplot()

ax.bar(positions_count.keys(), positions_count.to_list());

# %% [markdown]
# ## g. Club that has the most promising players and their numbers

# %%
promising_players = df[(df.Growth > 4) & (df.Potential > 84)]

max_count = promising_players['Club'].value_counts().max()
promising_players['Club'].value_counts()[promising_players['Club'].value_counts() == max_count]
# Out:
# Sporting CP    10
# Name: Club, dtype: int64

# %% [markdown]
# ## h. Number of players whom their contract is until 2021 and are not in national team

# %%
len(df[(df['ContractUntil'] == 2021) & (df['NationalTeam'] == 'Not in team')])
# Out:
# 6727

# %% [markdown]
# ## i. Report of ValueEUR for players whom their age is below 24 and are in Chelsea club

# %%
df[(df['Age'] < 24) & (df['Club'] == 'Chelsea')][['ValueEUR']].describe()
# Out:
#            ValueEUR
# count  1.200000e+01
# mean   2.800000e+07
# std    3.315794e+07
# min    5.000000e+05
# 25%    4.700000e+06
# 50%    2.225000e+07
# 75%    3.625000e+07
# max    1.210000e+08

# %% [markdown]
# ## j. Positions, WageEUR and Club report of E. Hazard

# %%
df[df['Name'] == 'E. Hazard'][['Name','FullName', 'ClubPosition', 'WageEUR', 'Club']]
# Out:
#          Name     FullName ClubPosition  WageEUR         Club
# 22  E. Hazard  Eden Hazard          SUB   350000  Real Madrid
